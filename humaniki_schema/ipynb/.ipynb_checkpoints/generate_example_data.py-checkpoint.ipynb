# %% [markdown]
# # GOALS
# 1. for each table in humaniki
# 2. generate an some example data
# 3. store it in CSV in /example_data # or skip straight to part 5
# 4. create a function to load the exmaple data into the database

# %%
from sqlalchemy import create_engine, func
from sqlalchemy.orm import sessionmaker
import datetime
import json
import os
# from humaniki_schema.schema import fill, human, human_country, human_occupation, human_property, human_sitelink, label, \
#                                     metric, metric_aggregations, metric_coverage, metric_properties
# import humaniki_schema.utils as hs_utils
from schema import fill, human, human_country, human_occupation, human_property, human_sitelink, label, \
                                    metric, metric_aggregations, metric_coverage, metric_properties
import utils as hs_utils

try:
    import pandas as pd
except ImportError:
    raise ImportError('For this script at least we need pandas')

# %%
data_dir = 'example_data'

# %%
db_engine = create_engine("mysql://{user}:{password}@{host}/{database}?charset=utf8".format(
    host = os.environ['HUMANIKI_MYSQL_HOST'],
    user = os.environ['HUMANIKI_MYSQL_USER'],
    password = os.environ['HUMANIKI_MYSQL_PASS'],
    database = os.environ['HUMANIKI_MYSQL_DB']))

# Base.metadata.bind = db_engine
DBSession = sessionmaker(bind=db_engine)
db_session = DBSession()

# %%
# Raw data
db_session.rollback()

# %%
#order is important becuse of foreign key constraint
all_tables = [human_country, human_occupation, human_property, human_sitelink, label, 
              metric_aggregations, metric_coverage, metric_properties,
                metric,
              human,
              fill,]

for table in all_tables:
    db_session.query(table).delete()
    db_session.commit()

# %%
def make_fills(n=2):
    fills = []
    for i in range(n):
        date = datetime.date(2018, 1, 1) + datetime.timedelta(weeks=i)
        ftype = hs_utils.FillType.DUMP.value
        detail = {'i':i, 'i_str': str(i)}
        a_fill = fill(date=date, type=ftype, detail=detail)
        fills.append(a_fill)

    db_session.rollback()
    db_session.add_all(fills)
    db_session.commit()
    return fills

fills = make_fills()
curr_fill = fills[0].id

# %%
def make_humans():
    humans_f = os.path.join(data_dir, 'denelezh_humans_500.tsv')

    humans_df = pd.read_csv(humans_f, sep='\t').rename(columns={"birthyear":'year_of_birth'})

    humans_df['year_of_death'] = humans_df['year_of_birth'].apply(lambda yob: yob+100 if yob is not None else None)

    humans_df = humans_df.replace(dict(year_of_birth={pd.np.nan: None}, year_of_death={pd.np.nan: None}))

    humans = []

    for fill in fills:
        fill_id = fill.id
        for ind, row in humans_df.iterrows():
            a_human = human(fill_id=fill_id, qid=row['id'], 
                            year_of_birth=row['year_of_birth'],
                            year_of_death=row['year_of_death'],
                           gender=row['gender'],
                           sitelink_count=row['sitelinks'])
            humans.append(a_human)

    db_session.rollback()
    db_session.add_all(humans)
    db_session.commit()
    return humans

humans = make_humans()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead

# %%
def make_table_from_file(fname, schema_table, table_tsv_map):
    table_f = os.path.join(data_dir, fname)
    table_df = pd.read_csv(table_f, sep='\t')
    insert_rows = []

    for fill in fills:
        fill_id = fill.id
        for ind, row in table_df.iterrows():
            params = {'fill_id':fill_id}
            for table_name, tsv_name in table_tsv_map.items():
                    params[table_name] = row[tsv_name]
            a_row = schema_table(**params)
            insert_rows.append(a_row)

    db_session.rollback()
    db_session.add_all(insert_rows)
    db_session.commit()
    return insert_rows

# %%
countries = make_table_from_file(fname='denelezh_human_country.tsv',
                                 schema_table=human_country,
                                table_tsv_map={'human_id':'human','country':'country'})

# %%
occupations = make_table_from_file(fname='denelezh_human_occupation.tsv',
                                    schema_table=human_occupation,
                                table_tsv_map={'human_id':'human','occupation':'occupation'})

# %%
sitelinks = make_table_from_file(fname='denelezh_human_sitelink.tsv', 
                                schema_table=human_sitelink,
                          table_tsv_map={'human_id':'human','sitelink':'sitelink'})

# %%
labels = make_table_from_file(fname='denelezh_label.tsv', 
                                schema_table=label,
                          table_tsv_map={'qid':'id','lang':'lang','label':'label'})

# %% [markdown]
# ## metrics
# 1. geographic metric
# 1. by language
# 2. multi - language / geography
# 3. multi - lanaguge / geography / occupation

# %%
def get_or_create_agg_vals(agg_vals):
#     agg_vals_rec = db_session.query(metric_aggregations).filter_by(aggregations=agg_vals).one_or_none()
        # select id, aggregations from metric_aggregations
        #     where json_length(aggregations)=2
        #         and json_extract(aggregations, '$[1]')=10
        #         and json_extract(aggregations, '$[0]')=6581097
    quoted_agg_vals = [f"'{val}'" if isinstance(val, str) else val for val in agg_vals] 
    agg_equals_parts = [ f"and json_extract(aggregations, '$[{pos}]')={val}" for pos, val in enumerate(quoted_agg_vals)]
    
    agg_equals_sql = f'''select id, aggregations from metric_aggregations where
                        json_length(aggregations)={len(agg_vals)}
                        {' '.join(agg_equals_parts)}
                        ;
                        '''
#     print(agg_equals_sql)
    agg_vals_rec = db_engine.execute(agg_equals_sql).fetchall()
#     print(agg_vals_rec)
    if not agg_vals_rec:
#         print(agg_vals , 'not found')
        a_metric_aggregation = metric_aggregations(aggregations=agg_vals)
        db_session.rollback()
        db_session.add(a_metric_aggregation)
        db_session.commit()
        return a_metric_aggregation.aggregations
    else:
        assert len(agg_vals_rec)==1
        return agg_vals_rec[0][0]

# %%
get_or_create_agg_vals([6581097, 'fff'])
# Out:
# [6581097, 'fff'] not found
# [6581097, 'fff']

# %%
def get_or_create_metric_props(metric_props):
#     metric_props_rec = db_session.query(metric_properties).filter_by(properties=metric_props).one_or_none()
    metric_equals_parts = [ f"and json_extract(properties, '$[{pos}]')={val}" for pos, val in enumerate(metric_props)]
    
    metric_equals_sql = f'''select id, properties from metric_properties where
                        json_length(properties)={len(metric_props)}
                        {' '.join(metric_equals_parts)}
                        ;
                        '''
#     print(metric_equals_sql)
    metric_props_rec = db_engine.execute(metric_equals_sql).fetchall()
    if not metric_props_rec:
#         print(metric_props)
        a_metric_properties = metric_properties(properties=metric_props)
        db_session.rollback()
        db_session.add(a_metric_properties)
        db_session.commit()
        return a_metric_properties.properties
    else:
        assert len(metric_props_rec)==1
        return metric_props_rec[0][0]

# %%
get_or_create_agg_vals([6581097, 13])
# Out:
# 310

# %%
m_props = get_or_create_metric_props([-1])
# Out:
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [-1]

# %%
def generate_geo_metrics():
    geo_metric_q = db_session.query(human.gender, human_country.country, func.count(human.gender)) \
    .join(human_country).filter(human.fill_id==curr_fill)\
    .group_by(human_country.country, human.gender)

    geo_metric_res = geo_metric_q.all()

    print(str(geo_metric_q))

#     geo_metric_q = db_session.query(human.gender, human_country.country, func.count(human.gender)) \
#     .join(human_country).filter(human.fill_id==curr_fill)\
#     .group_by(human_country.country, human.gender)

#     geo_metric_res = geo_metric_q.all()
    return geo_metric_res
geo_metric_res = generate_geo_metrics()
# Out:
# SELECT human.gender AS human_gender, human_country.country AS human_country_country, count(human.gender) AS count_1
# FROM human INNER JOIN human_country ON human.qid = human_country.human_id
# WHERE human.fill_id = %s GROUP BY human_country.country, human.gender

# %%
def insert_geo_metrics():
    geo_metrics = []
    for gender, country, count in geo_metric_res:
        agg_vals_id = get_or_create_agg_vals([gender, country])
        m_props_id = get_or_create_metric_props([-1])
    #     db_session.commit()
        fills_id = curr_fill
        db_session.rollback()
        a_metric = metric(fill_id=fills_id,
                         facet='geography',
                         population='all-wikidata',
                         properties_id=m_props_id,
                         aggregation_vals=agg_vals_id,
                         bias_value=gender,
                         total=count)
        geo_metrics.append(a_metric)
        db_session.commit()
    return geo_metrics
geo_metrics = insert_geo_metrics()
# Out:
# [6581097, 30] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 161885] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 145] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 142] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 16] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 12548] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 70972] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 29] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 4948] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 298] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 154849] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581072, 298] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 39] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 7318] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 28513] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 41304] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 29999] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 408] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 736] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 2895] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 34266] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 213] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 33946] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581072, 30] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 766] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 36] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 154195] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 35] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 15180] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 34] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 165154] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 172579] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581072, 142] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581072, 183] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
# [6581072, 16957] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 17] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 38] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 414] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 1649871] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581072, 11768] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581072, 145] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 183] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 179876] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 159] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 2305208] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 844930] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 207272] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 20] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 43287] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581072, 40] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581072, 408] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 129286] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 1775277] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 131964] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 174193] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 668] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 1747689] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581072, 668] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581072, 129286] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581072, 1775277] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 884] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 117] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 79] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 419] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 40] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 836] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 796] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 851] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
# [6581097, 2184] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 258] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581072, 218] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 928] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581072, 928] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 217196] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 11768] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 170174] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 1041] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [2449503, 30] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 769] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 786] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 754] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 114] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 963] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 262] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 31] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 1028] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 115] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 1183] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 1036] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 148] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 774] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 846] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 1044] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 16957] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 794] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 191] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 28] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 215] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 83286] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 399] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 241] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 948] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
# [6581072, 34] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 96] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581072, 39] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581072, 38] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 32] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581072, 1747689] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 41] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 713750] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 27306] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 184] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581072, 174193] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;
#
# [6581097, 6581823] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-1
#                         ;

# %%
curr_fill
# Out:
# 51

# %%
str(human.gender), str(func.count(human.gender))
# Out:
# ('human.gender', 'count(human.gender)')

# %%
def generate_single_facet_metric(agg_table, agg_table_col):
    query_columns = human.gender, agg_table_col, func.count(human.gender)
    query_columns_str = [str(c) for c in query_columns]
    metric_q = db_session.query(*query_columns) \
    .join(agg_table).filter(human.fill_id==curr_fill)\
    .group_by(agg_table_col, human.gender)

    metric_res = metric_q.all()

#     print(str(metric_q))
    return query_columns_str, metric_res

proj_metric_strs, proj_metric_res = generate_single_facet_metric(human_sitelink, human_sitelink.sitelink)

def get_props_id_from_str(prop):
    return {'sitelink':-2}[prop]

def insert_single_prop_metrics(facet, prop, metric_col_strs, metric_rows):
    sf_metrics = []
    for gender, prop_val, count in metric_rows:
        agg_vals_id = get_or_create_agg_vals([gender, prop_val])
        props_pid = get_props_id_from_str(prop)
        m_props_id = get_or_create_metric_props([props_pid])
    #     db_session.commit()
        fills_id = curr_fill
        db_session.rollback()
        a_metric = metric(fill_id=fills_id,
                         facet=facet,
                         population='all-wikidata',
                         properties_id=m_props_id,
                         aggregation_vals=agg_vals_id,
                         bias_value=gender,
                         total=count)
        sf_metrics.append(a_metric)

    db_session.add_all(sf_metrics)
    db_session.commit()
    return sf_metrics
metrics = insert_single_prop_metrics(facet='project', prop='sitelink', 
                                     metric_col_strs=proj_metric_strs, 
                                     metric_rows=proj_metric_res)
# Out:
# SELECT human.gender AS human_gender, human_sitelink.sitelink AS human_sitelink_sitelink, count(human.gender) AS count_1
# FROM human INNER JOIN human_sitelink ON human.qid = human_sitelink.human_id
# WHERE human.fill_id = %s GROUP BY human_sitelink.sitelink, human.gender
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [-2]
# [6581097, 'acewiki'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'afwiki'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'akwiki'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'alswiki'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'amwiki'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'angwiki'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'anwiki'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'arcwiki'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'arwiki'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'arwikiquote'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'arzwiki'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'astwiki'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'awawiki'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'aywiki'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'azbwiki'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'azwiki'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'azwikiquote'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'azwikisource'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'barwiki'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;
#
# [6581097, 'bat_smgwiki'] not found
# select id, properties from metric_properties where
#                         json_length(properties)=1
#                         and json_extract(properties, '$[0]')=-2
#                         ;

# %%
# proj_metric_res
# Out:
# [(6581097, 'abwiki', 42),
#  (6581097, 'acewiki', 34),
#  (6581097, 'afwiki', 426),
#  (6581097, 'akwiki', 30),
#  (6581097, 'alswiki', 248),
#  (6581097, 'amwiki', 184),
#  (6581097, 'angwiki', 84),
#  (6581097, 'anwiki', 364),
#  (6581097, 'arcwiki', 28),
#  (6581097, 'arwiki', 810),
#  (6581097, 'arwikiquote', 104),
#  (6581097, 'arzwiki', 758),
#  (6581097, 'astwiki', 508),
#  (6581097, 'awawiki', 22),
#  (6581097, 'aywiki', 142),
#  (6581097, 'azbwiki', 402),
#  (6581097, 'azwiki', 462),
#  (6581097, 'azwikiquote', 148),
#  (6581097, 'azwikisource', 14),
#  (6581097, 'barwiki', 134),
#  (6581097, 'bat_smgwiki', 146),
#  (6581097, 'bawiki', 180),
#  (6581097, 'bclwiki', 126),
#  (6581097, 'bewiki', 584),
#  (6581097, 'bewikiquote', 54),
#  (6581097, 'be_x_oldwiki', 412),
#  (6581097, 'bgwiki', 618),
#  (6581097, 'bgwikiquote', 214),
#  (6581097, 'bgwikisource', 8),
#  (6581097, 'bhwiki', 88),
#  (6581097, 'biwiki', 118),
#  (6581097, 'bjnwiki', 24),
#  (6581097, 'bnwiki', 346),
#  (6581097, 'brwiki', 458),
#  (6581097, 'bswiki', 392),
#  (6581097, 'bswikiquote', 142),
#  (6581097, 'bxrwiki', 106),
#  (6581097, 'cawiki', 716),
#  (6581097, 'cawikiquote', 158),
#  (6581097, 'cdowiki', 86),
#  (6581097, 'cebwiki', 108),
#  (6581097, 'cewiki', 120),
#  (6581097, 'chrwiki', 16),
#  (6581097, 'ckbwiki', 228),
#  (6581097, 'commonswiki', 774),
#  (6581097, 'cowiki', 110),
#  (6581097, 'cswiki', 764),
#  (6581097, 'cswikiquote', 296),
#  (6581097, 'cvwiki', 158),
#  (6581097, 'cywiki', 408),
#  (6581097, 'dawiki', 682),
#  (6581097, 'dewiki', 900),
#  (6581097, 'dewikiquote', 246),
#  (6581097, 'cswikisource', 78),
#  (6581097, 'krcwiki', 12),
#  (6581097, 'rowikibooks', 2),
#  (6581097, 'tiwiki', 6),
#  (6581097, 'xalwiki', 20),
#  (6581097, 'arywiki', 24),
#  (6581097, 'fjwiki', 12),
#  (6581097, 'glwikisource', 8),
#  (6581097, 'kbdwiki', 42),
#  (6581097, 'avkwiki', 56),
#  (6581097, 'lldwiki', 38),
#  (6581097, 'piwiki', 6),
#  (6581097, 'angwikiquote', 2),
#  (6581097, 'lawikisource', 52),
#  (6581097, 'novwiki', 30),
#  (6581097, 'tcywiki', 18),
#  (6581097, 'uzwikiquote', 16),
#  (6581072, 'afwiki', 30),
#  (6581072, 'alswiki', 16),
#  (6581072, 'amwiki', 8),
#  (6581072, 'arwiki', 64),
#  (6581072, 'arzwiki', 62),
#  (6581072, 'astwiki', 30),
#  (6581072, 'azwiki', 32),
#  (6581072, 'barwiki', 10),
#  (6581072, 'bewiki', 34),
#  (6581072, 'be_x_oldwiki', 18),
#  (6581072, 'bgwiki', 46),
#  (6581072, 'bnwiki', 20),
#  (6581072, 'brwiki', 30),
#  (6581072, 'bswiki', 22),
#  (6581072, 'cawiki', 60),
#  (6581072, 'cbk_zamwiki', 6),
#  (6581072, 'commonswiki', 52),
#  (6581072, 'cswiki', 60),
#  (6581072, 'dawiki', 48),
#  (6581072, 'dewiki', 76),
#  (6581072, 'diqwiki', 10),
#  (6581072, 'elwiki', 36),
#  (6581072, 'enwiki', 76),
#  (6581072, 'enwikinews', 4),
#  (6581072, 'enwikisource', 10),
#  (6581072, 'eowiki', 44),
#  (6581072, 'eswiki', 72),
#  (6581072, 'eswikinews', 6),
#  (6581072, 'eswikiquote', 20),
#  (6581072, 'eswikisource', 2),
#  (6581072, 'etwiki', 42),
#  (6581072, 'euwiki', 48),
#  (6581072, 'fawiki', 64),
#  (6581072, 'fiwiki', 64),
#  (6581072, 'frwiki', 70),
#  (6581072, 'gawiki', 30),
#  (6581072, 'glwiki', 42),
#  (6581072, 'hewiki', 52),
#  (6581072, 'hiwiki', 18),
#  (6581072, 'hrwiki', 42),
#  (6581072, 'huwiki', 50),
#  (6581072, 'idwiki', 40),
#  (6581072, 'ilowiki', 12),
#  (6581072, 'iowiki', 32),
#  (6581072, 'iswiki', 26),
#  (6581072, 'itwiki', 70),
#  (6581072, 'itwikiquote', 26),
#  (6581072, 'jawiki', 62),
#  (6581072, 'kawiki', 32),
#  (6581072, 'kkwiki', 20),
#  (6581072, 'knwiki', 12),
#  (6581072, 'kowiki', 52),
#  (6581072, 'ladwiki', 8),
#  (6581072, 'lawiki', 26),
#  (6581072, 'lbwiki', 22),
#  (6581072, 'ltwiki', 28),
#  (6581072, 'lvwiki', 32),
#  (6581072, 'mgwiki', 22),
#  (6581072, 'mlwiki', 20),
#  (6581072, 'mrwiki', 20),
#  (6581072, 'mswiki', 22),
#  (6581072, 'mznwiki', 8),
#  (6581072, 'newwiki', 6),
#  (6581072, 'nlwiki', 66),
#  (6581072, 'nnwiki', 38),
#  (6581072, 'nowiki', 64),
#  (6581072, 'ocwiki', 62),
#  (6581072, 'orwiki', 6),
#  (6581072, 'pamwiki', 6),
#  (6581072, 'pawiki', 18),
#  (6581072, 'plwiki', 66),
#  (6581072, 'plwikiquote', 24),
#  (6581072, 'pnbwiki', 12),
#  (6581072, 'pswiki', 4),
#  (6581072, 'ptwiki', 60),
#  (6581072, 'quwiki', 18),
#  (6581072, 'rowiki', 48),
#  (6581072, 'ruwiki', 72),
#  (6581072, 'ruwikinews', 22),
#  (6581072, 'ruwikiquote', 18),
#  (6581072, 'scnwiki', 14),
#  (6581072, 'scowiki', 32),
#  (6581072, 'shwiki', 40),
#  (6581072, 'simplewiki', 44),
#  (6581072, 'siwiki', 8),
#  (6581072, 'skwiki', 46),
#  (6581072, 'srwiki', 54),
#  (6581072, 'svwiki', 70),
#  (6581072, 'szywiki', 2),
#  (6581072, 'tawiki', 24),
#  (6581072, 'tewiki', 10),
#  (6581072, 'tgwiki', 14),
#  (6581072, 'thwiki', 34),
#  (6581072, 'tlwiki', 26),
#  (6581072, 'trwiki', 46),
#  (6581072, 'ukwiki', 58),
#  (6581072, 'urwiki', 22),
#  (6581072, 'uzwiki', 18),
#  (6581072, 'viwiki', 38),
#  (6581072, 'warwiki', 20),
#  (6581072, 'wuuwiki', 32),
#  (6581072, 'yiwiki', 12),
#  (6581072, 'yowiki', 14),
#  (6581072, 'zhwiki', 46),
#  (6581072, 'zh_min_nanwiki', 20),
#  (6581072, 'zh_yuewiki', 22),
#  (6581097, 'koiwiki', 2),
#  (6581097, 'nnwikiquote', 26),
#  (6581097, 'iswikiquote', 30),
#  (6581097, 'lgwiki', 8),
#  (6581097, 'nowikisource', 16),
#  (6581097, 'plwikibooks', 4),
#  (6581097, 'stwiki', 12),
#  (6581072, 'mkwiki', 24),
#  (6581097, 'bewikisource', 8),
#  (6581097, 'kvwiki', 4),
#  (6581072, 'azbwiki', 40),
#  (6581072, 'bxrwiki', 4),
#  (6581072, 'enwikiquote', 30),
#  (6581072, 'fawikiquote', 6),
#  (6581072, 'fywiki', 26),
#  (6581072, 'lmowiki', 6),
#  (6581072, 'newiki', 16),
#  (6581072, 'nowikiquote', 2),
#  (6581072, 'vowiki', 12),
#  (6581072, 'cswikiquote', 20),
#  (6581072, 'maiwiki', 10),
#  (6581072, 'slwiki', 40),
#  (6581097, 'pflwiki', 6),
#  (6581097, 'mdfwiki', 8),
#  (6581097, 'bswikisource', 2),
#  (6581097, 'hrwikisource', 16),
#  (6581097, 'huwikisource', 38),
#  (6581097, 'hywikisource', 18),
#  (6581097, 'ltwikisource', 10),
#  (6581097, 'rowikisource', 26),
#  (6581097, 'slwikisource', 16),
#  (6581097, 'nlwikisource', 20),
#  (6581097, 'eewiki', 2),
#  (6581097, 'shnwiki', 4),
#  (6581097, 'twwiki', 20),
#  (6581097, 'specieswiki', 12),
#  (6581097, 'frwikiversity', 8),
#  (6581097, 'pawikisource', 10),
#  (6581072, 'anwiki', 20),
#  (6581072, 'bclwiki', 10),
#  (6581072, 'cywiki', 22),
#  (6581072, 'emlwiki', 12),
#  (6581072, 'hywiki', 46),
#  (6581072, 'iewiki', 8),
#  (6581072, 'sqwiki', 20),
#  (6581072, 'kowikisource', 2),
#  (6581072, 'mrjwiki', 4),
#  (6581072, 'swwiki', 20),
#  (6581072, 'ukwikiquote', 18),
#  (6581072, 'frwikiquote', 14),
#  (6581072, 'papwiki', 4),
#  (6581072, 'arwikinews', 2),
#  (6581072, 'arywiki', 2),
#  (6581072, 'aywiki', 10),
#  (6581072, 'azwikiquote', 10),
#  (6581072, 'bawiki', 12),
#  (6581072, 'bewikiquote', 2),
#  (6581072, 'bgwikiquote', 14),
#  (6581072, 'bhwiki', 4),
#  (6581072, 'biwiki', 6),
#  (6581072, 'bowiki', 2),
#  (6581072, 'cawikiquote', 8),
#  (6581072, 'ckbwiki', 10),
#  (6581072, 'cswikinews', 4),
#  (6581072, 'cswikisource', 2),
#  (6581072, 'cvwiki', 4),
#  (6581072, 'cywikiquote', 4),
#  (6581072, 'dewikinews', 4),
#  (6581072, 'dewikiquote', 8),
#  (6581072, 'dsbwiki', 6),
#  (6581072, 'dtywiki', 4),
#  (6581072, 'elwikiquote', 4),
#  (6581072, 'eowikinews', 2),
#  (6581072, 'etwikiquote', 4),
#  (6581072, 'extwiki', 2),
#  (6581072, 'fiwikiquote', 6),
#  (6581072, 'fowiki', 14),
#  (6581072, 'frpwiki', 2),
#  (6581072, 'frrwiki', 4),
#  (6581072, 'frwikinews', 4),
#  (6581072, 'gdwiki', 8),
#  (6581072, 'gvwiki', 2),
#  (6581072, 'hakwiki', 2),
#  (6581072, 'hawiki', 6),
#  (6581072, 'hsbwiki', 6),
#  (6581072, 'huwikinews', 2),
#  (6581072, 'iawiki', 12),
#  (6581072, 'idwikiquote', 6),
#  (6581072, 'itwikinews', 2),
#  (6581072, 'jawikiquote', 4),
#  (6581072, 'jvwiki', 12),
#  (6581072, 'kbpwiki', 6),
#  (6581072, 'koiwiki', 4),
#  (6581072, 'kowikinews', 2),
#  (6581072, 'kuwiki', 10),
#  (6581072, 'kwwiki', 2),
#  (6581072, 'kywiki', 6),
#  (6581072, 'liwiki', 6),
#  (6581072, 'mhrwiki', 6),
#  (6581072, 'mnwiki', 16),
#  (6581072, 'mywiki', 14),
#  (6581072, 'ndswiki', 12),
#  (6581072, 'nlwikinews', 2),
#  (6581072, 'nlwikiquote', 4),
#  (6581072, 'novwiki', 2),
#  (6581072, 'pagwiki', 4),
#  (6581072, 'pdcwiki', 2),
#  (6581072, 'pihwiki', 2),
#  (6581072, 'ptwikinews', 2),
#  (6581072, 'sahwiki', 4),
#  (6581072, 'sewiki', 2),
#  (6581072, 'slwikiquote', 6),
#  (6581072, 'srwikinews', 2),
#  (6581072, 'stqwiki', 6),
#  (6581072, 'svwikinews', 2),
#  (6581072, 'szlwiki', 6),
#  (6581072, 'tetwiki', 2),
#  (6581072, 'thwikiquote', 4),
#  (6581072, 'trwikinews', 2),
#  (6581072, 'trwikiquote', 10),
#  (6581072, 'ttwiki', 10),
#  (6581072, 'tywiki', 2),
#  (6581072, 'zeawiki', 2),
#  (6581072, 'zhwikinews', 2),
#  (6581072, 'atjwiki', 2),
#  (6581072, 'scwiki', 8),
#  (6581097, 'lawikiquote', 30),
#  (6581072, 'awawiki', 2),
#  (6581072, 'banwiki', 2),
#  (6581072, 'bat_smgwiki', 6),
#  (6581072, 'cdowiki', 4),
#  (6581072, 'cebwiki', 6),
#  (6581072, 'fiu_vrowiki', 2),
#  (6581072, 'ganwiki', 4),
#  (6581072, 'gomwiki', 6),
#  (6581072, 'jamwiki', 2),
#  (6581072, 'lfnwiki', 2),
#  (6581072, 'lijwiki', 2),
#  (6581072, 'map_bmswiki', 4),
#  (6581072, 'mtwiki', 4),
#  (6581072, 'mwlwiki', 4),
#  (6581072, 'napwiki', 2),
#  (6581072, 'sawiki', 4),
#  (6581072, 'sdwiki', 6),
#  (6581072, 'suwiki', 2),
#  (6581072, 'liwikiquote', 2),
#  (6581097, 'adywiki', 10),
#  (6581097, 'srwikisource', 4),
#  (6581097, 'itwikibooks', 14),
#  (6581097, 'nlwikibooks', 8),
#  (6581097, 'napwikisource', 6),
#  (6581097, 'euwikisource', 10),
#  (6581097, 'pntwiki', 10),
#  (6581097, 'frwikibooks', 2),
#  (6581097, 'etwikisource', 4),
#  (6581097, 'itwikiversity', 14),
#  (6581072, 'hewikiquote', 8),
#  (6581072, 'htwiki', 4),
#  (6581072, 'kabwiki', 6),
#  (6581072, 'myvwiki', 2),
#  (6581072, 'pmswiki', 4),
#  (6581072, 'ptwikiquote', 12),
#  (6581072, 'vecwiki', 4),
#  (6581072, 'xmfwiki', 10),
#  (6581097, 'jawikibooks', 2),
#  (6581097, 'srwikibooks', 2),
#  (6581097, 'enwikivoyage', 4),
#  (6581097, 'zh_min_nanwikiquote', 4),
#  (6581097, 'sawikiquote', 2),
#  (6581097, 'wowiki', 10),
#  (6581097, 'plwikinews', 8),
#  (6581097, 'rowikinews', 2),
#  (6581097, 'kywikiquote', 2),
#  (6581097, 'guwikiquote', 2),
#  (6581097, 'guwikisource', 2),
#  (6581097, 'sswiki', 2),
#  (6581097, 'mkwikisource', 2),
#  (6581097, 'inhwiki', 2),
#  (6581097, 'crwiki', 2),
#  (6581097, 'sgwiki', 2),
#  (6581097, 'vewiki', 2),
#  (6581097, 'lijwikisource', 2),
#  (6581072, 'arwikiquote', 4),
#  (6581072, 'aswiki', 2),
#  (6581072, 'bswikiquote', 8),
#  (6581072, 'guwiki', 2),
#  (6581072, 'hifwiki', 4),
#  (6581072, 'hiwikiquote', 2),
#  (6581072, 'hywikiquote', 4),
#  (6581072, 'kawikiquote', 6),
#  (6581072, 'kswiki', 2),
#  (6581072, 'ltwikiquote', 6),
#  (6581072, 'satwiki', 2),
#  (6581072, 'srwikiquote', 2),
#  (6581072, 'tawikiquote', 2),
#  (6581072, 'tcywiki', 2),
#  (6581072, 'tewikiquote', 2),
#  (6581072, 'tkwiki', 2),
#  (6581072, 'xalwiki', 2),
#  (6581097, 'wowikiquote', 2),
#  (6581097, 'bugwiki', 4),
#  (6581097, 'mkwikibooks', 10),
#  (6581097, 'tawikisource', 2),
#  (6581072, 'kmwiki', 2),
#  (6581072, 'skwikiquote', 6),
#  (6581072, 'nahwiki', 4),
#  (6581072, 'abwiki', 2),
#  (6581072, 'cewiki', 2),
#  (6581072, 'eowikiquote', 4),
#  (6581072, 'hywwiki', 2),
#  (6581072, 'pcdwiki', 2),
#  (6581072, 'ruewiki', 2),
#  (6581072, 'vepwiki', 4),
#  (6581072, 'svwikiquote', 4),
#  (6581072, 'zhwikiquote', 2),
#  (2449503, 'arzwiki', 2),
#  (2449503, 'azwiki', 2),
#  (2449503, 'bgwiki', 2),
#  (2449503, 'bnwiki', 2),
#  (2449503, 'cawiki', 2),
#  (2449503, 'commonswiki', 2),
#  (2449503, 'cswiki', 2),
#  (2449503, 'dawiki', 2),
#  (2449503, 'dewiki', 2),
#  (2449503, 'elwiki', 2),
#  (2449503, 'enwiki', 2),
#  (2449503, 'eswiki', 2),
#  (2449503, 'etwiki', 2),
#  (2449503, 'euwiki', 2),
#  (2449503, 'fawiki', 2),
#  (2449503, 'fiwiki', 2),
#  (2449503, 'frwiki', 2),
#  (2449503, 'hewiki', 2),
#  (2449503, 'hrwiki', 2),
#  (2449503, 'huwiki', 2),
#  (2449503, 'idwiki', 2),
#  (2449503, 'iowiki', 2),
#  (2449503, 'itwiki', 2),
#  (2449503, 'jawiki', 2),
#  (2449503, 'kowiki', 2),
#  (2449503, 'lawiki', 2),
#  (2449503, 'ltwiki', 2),
#  (2449503, 'lvwiki', 2),
#  (2449503, 'mkwiki', 2),
#  (2449503, 'mlwiki', 2),
#  (2449503, 'mnwiki', 2),
#  (2449503, 'mrwiki', 2),
#  (2449503, 'mswiki', 2),
#  (2449503, 'nlwiki', 2),
#  (2449503, 'nnwiki', 2),
#  (2449503, 'nowiki', 2),
#  (2449503, 'pawiki', 2),
#  (2449503, 'plwiki', 2),
#  (2449503, 'ptwiki', 2),
#  (2449503, 'ruwiki', 2),
#  (2449503, 'scowiki', 2),
#  (2449503, 'shwiki', 2),
#  (2449503, 'skwiki', 2),
#  (2449503, 'srwiki', 2),
#  (2449503, 'svwiki', 2),
#  (2449503, 'tawiki', 2),
#  (2449503, 'trwiki', 2),
#  (2449503, 'ukwiki', 2),
#  (2449503, 'zhwiki', 2),
#  (6581072, 'avwiki', 2),
#  (6581072, 'cowiki', 2),
#  (6581072, 'csbwiki', 2),
#  (6581072, 'hrwikiquote', 4),
#  (6581072, 'igwiki', 2),
#  (6581072, 'ikwiki', 2),
#  (6581072, 'jbowiki', 2),
#  (6581072, 'kvwiki', 2),
#  (6581072, 'nds_nlwiki', 2),
#  (6581072, 'rowikiquote', 2),
#  (6581072, 'sowiki', 2),
#  (6581072, 'vlswiki', 2),
#  (6581072, 'wawiki', 2),
#  (6581097, 'pmswikisource', 2),
#  (6581097, 'dewikivoyage', 4),
#  (6581097, 'hewikinews', 2),
#  (6581097, 'atjwiki', 2),
#  (6581097, 'ffwiki', 2),
#  (6581097, 'ikwiki', 2),
#  (6581097, 'rnwiki', 2)]
